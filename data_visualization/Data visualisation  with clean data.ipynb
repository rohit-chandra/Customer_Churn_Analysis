# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Importing Necessary Python Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import ppscore as pps
import matplotlib.pyplot as plt
import missingno as msno
import warnings
warnings.filterwarnings('ignore')

# %%
def readData(pathName):
    df = pd.read_csv(pathName)
    return df

# %%
def countplot(x1,x2,x3,x4,df):
    fig,ax = plt.subplots(1,4)
    sns.set_style("dark")
    sns.set(rc={'figure.figsize':(10,10)})
    sns.countplot(x=x1, data=df, palette=sns.color_palette("Paired", 7), saturation=10, ax = ax[0])
    sns.countplot(x=x2, data=df, palette=sns.color_palette("Paired", 7), saturation=10, ax = ax[1])
    sns.countplot(x=x3, data=df, palette=sns.color_palette("Paired", 7), saturation=10, ax = ax[2])
    sns.countplot(x=x4, data=df, palette=sns.color_palette("Paired", 7), saturation=10, ax = ax[3])

    fig.suptitle('Count plot',fontsize = 20);
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.7, 
                    hspace=0.4)
    fig.show()
    plt.show()
    print('Count plot - The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable')
    print('\nWe will display the target variable and check for data imbalance using this Count plot (if there are more number of churn customers than customers who wont churn or vice versa)')
    print('\nObservation1:\nThere is some data imbalance, as the number of churn consumers is significantly lower than the number of customers that will not churn')
    print('\nUsing count plot, lets see the frequency/count of different age group')
    print('\nAgegroup Range \n[0-15]    :   1\n[15-30]   :   2\n[30-45]   :   3\n[45-60]   :   4\n[60-80]   :   5\n[<0,>80]  :   2')    
    print('\nObservation2:\nThere are more people between the ages of 15 and 45')
    print('\nCharge amount is an ordinal attribute with lowest value being 0 and highest being 9')
    print('\nObservation3:\nThe charge amount of 0 has the highest count')

# %%
def Distribution_plot(df):
    fig, axarr = plt.subplots(2,2, figsize=(17,12), dpi=80, facecolor='w', edgecolor='k')
    sns.set(style="white")
    sns.countplot(x='ageGroup', hue = 'Churn',data = df, ax=axarr[0][0], palette="Accent_r")
    sns.countplot(x='status', hue = 'Churn',data = df, ax=axarr[0][1], palette="Accent_r")
    sns.countplot(x='call_failure', hue = 'complains',data = df,ax=axarr[1][0], palette="Accent_r")
    sns.countplot(x='charge_amount', hue = 'ageGroup',data = df, ax=axarr[1][1], palette="Accent_r")
    fig.suptitle('Frequency Distribution of Different Categorical Variable',fontsize = 20);
    plt.show()
    print('Observation1\n We observe that there are many customers who are in the age group 30-60 and  are less likely to churn')
    print('Observation2\n We observe that the difference in count is huge between churn and non churn active customers(where active customers are more likely to not churn) as that of churn and non churn inactive customers')
    print('Observation3\n We observe that more number of customers have 0 call failures and hence 0 complaints')
    print('Observation4\n We observe that more number of customers who are in the age group of 30-60 have charge amount as o which refers to lowest pay ')

# %%
def pie(df):
    plt.pie(df['ageGroup'].value_counts(), labels=df['ageGroup'].value_counts().index.tolist(), autopct='%1.0f%%',shadow = True)
    plt.title('Pie Chart wrt AgeGroup',fontsize = 20);
    #plt.savefig('Distribution_pie_chart.png')
    plt.show()
    print('Observation\nAs we can see from the pie chart, most of the customers are of the age group 30-45')

# %%
def boxplot(df):
    
    sns.set(style="whitegrid",font_scale=1)
    plt.figure(figsize=(10,8))
    sns.boxplot(data=df)
    plt.xticks(rotation=80)
    plt.title("Box plot For Outlier Analysis",fontsize = 20)
    plt.show()
    print('outlier analysis using box-plot')
    print('Observation\nAs we can see there are outliers in our dataset, especially in seconds_of_use column we have more outliers')

# %%
def pairplot(df):
    df["Churn"] = np.random.choice([1., 0.], size=len(df))
    sns.pairplot(df,vars=df.columns[:7], corner=True, hue = 'Churn' )
    plt.show()

# %%
    # %matplotlib inline
    df = readData('../data/churn_final.csv')
    corr = df.corr()
    cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

    def magnify():
        return [dict(selector="th",
                     props=[("font-size", "7pt")]),
                dict(selector="td",
                     props=[('padding', "0em 0em")]),
                dict(selector="th:hover",
                     props=[("font-size", "12pt")]),
                dict(selector="tr:hover td:hover",
                     props=[('max-width', '200px'),
                            ('font-size', '12pt')])
    ]

    corr.style.background_gradient(cmap, axis=1)\
        .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
        .set_caption("Hover to magify")\
        .set_precision(2)\
        .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_37583_ th {
#           font-size: 7pt;
#     }    #T_37583_ td {
#           padding: 0em 0em;
#     }    #T_37583_ th:hover {
#           font-size: 12pt;
#     }    #T_37583_ tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }#T_37583_row0_col0,#T_37583_row1_col1,#T_37583_row2_col2,#T_37583_row3_col3,#T_37583_row4_col4,#T_37583_row5_col5,#T_37583_row6_col6,#T_37583_row7_col7,#T_37583_row8_col8,#T_37583_row9_col9,#T_37583_row10_col10,#T_37583_row11_col11,#T_37583_row12_col12,#T_37583_row12_col13,#T_37583_row12_col14,#T_37583_row13_col12,#T_37583_row13_col13,#T_37583_row13_col14,#T_37583_row14_col12,#T_37583_row14_col13,#T_37583_row14_col14,#T_37583_row15_col15{
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col1,#T_37583_row6_col2{
#             background-color:  #e494a4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col2,#T_37583_row6_col3{
#             background-color:  #e599a8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col3{
#             background-color:  #c5d3e4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col4,#T_37583_row4_col12,#T_37583_row4_col13{
#             background-color:  #dfe5ed;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col5{
#             background-color:  #c9d6e6;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col6{
#             background-color:  #dc5973;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col7{
#             background-color:  #dee4ec;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col8,#T_37583_row7_col6{
#             background-color:  #e6a1af;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col9,#T_37583_row1_col12,#T_37583_row1_col13,#T_37583_row1_col14,#T_37583_row2_col8,#T_37583_row3_col9,#T_37583_row4_col9,#T_37583_row5_col9,#T_37583_row6_col15,#T_37583_row7_col9,#T_37583_row7_col15,#T_37583_row8_col2,#T_37583_row9_col4,#T_37583_row10_col1,#T_37583_row11_col1,#T_37583_row12_col15,#T_37583_row13_col15,#T_37583_row14_col15,#T_37583_row15_col4,#T_37583_row15_col5{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col10,#T_37583_row6_col4{
#             background-color:  #e69caa;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col11,#T_37583_row1_col9,#T_37583_row6_col5{
#             background-color:  #e59aa9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col12,#T_37583_row0_col13{
#             background-color:  #e3889a;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col14,#T_37583_row2_col6,#T_37583_row2_col9,#T_37583_row10_col0{
#             background-color:  #e28497;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row0_col15{
#             background-color:  #dc5e77;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row1_col0,#T_37583_row4_col10,#T_37583_row8_col4{
#             background-color:  #e597a7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row1_col2{
#             background-color:  #dd5f78;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row1_col3,#T_37583_row6_col1{
#             background-color:  #dc5b75;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row1_col4,#T_37583_row9_col3,#T_37583_row9_col7,#T_37583_row9_col12,#T_37583_row9_col13{
#             background-color:  #d84462;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row1_col5,#T_37583_row10_col6,#T_37583_row11_col6,#T_37583_row11_col8{
#             background-color:  #d94a67;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row1_col6{
#             background-color:  #d84361;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row1_col7,#T_37583_row11_col2{
#             background-color:  #db546f;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row1_col8,#T_37583_row2_col1,#T_37583_row11_col3{
#             background-color:  #de667e;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row1_col10,#T_37583_row1_col11{
#             background-color:  #dc5c76;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row1_col15{
#             background-color:  #d4dde9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row2_col0{
#             background-color:  #e7a3b0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row2_col3,#T_37583_row15_col2{
#             background-color:  #e28698;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row2_col4,#T_37583_row7_col10{
#             background-color:  #e492a3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row2_col5,#T_37583_row2_col12,#T_37583_row2_col13,#T_37583_row2_col14{
#             background-color:  #e48fa0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row2_col7,#T_37583_row14_col11,#T_37583_row15_col10{
#             background-color:  #e38a9c;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row2_col10{
#             background-color:  #e17d91;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row2_col11,#T_37583_row7_col1{
#             background-color:  #e17a8f;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row2_col15{
#             background-color:  #dd627b;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row3_col0,#T_37583_row5_col0{
#             background-color:  #b6c9e0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row3_col1,#T_37583_row6_col10,#T_37583_row6_col11{
#             background-color:  #e18093;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row3_col2{
#             background-color:  #e6a0ae;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row3_col4{
#             background-color:  #dce3ec;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row3_col5{
#             background-color:  #eff0f2;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_37583_row3_col6,#T_37583_row3_col11,#T_37583_row7_col2,#T_37583_row8_col7{
#             background-color:  #e7a4b1;
#             color:  #000000;
#             max-width:  80px;

# %%
def correlation(df):
    corr = df.corr()
    cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)
    def magnify():
        return [dict(selector="th",
                     props=[("font-size", "7pt")]),
                dict(selector="td",
                     props=[('padding', "0em 0em")]),
                dict(selector="th:hover",
                     props=[("font-size", "12pt")]),
                dict(selector="tr:hover td:hover",
                     props=[('max-width', '200px'),
                            ('font-size', '12pt')])
    ]
    corr.style.background_gradient(cmap, axis=1)\
        .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
        .set_caption("Hover to magify")\
        .set_precision(2)\
        .set_table_styles(magnify())

# %%
#heatmap for correlation coefficient

def plotHeatMap(df):
    df_corr = df.corr()

    # correlation matrix
    sns.set(font_scale=0.8)
    plt.figure(figsize=(16,12))
    sns.heatmap(df_corr, annot=True, fmt=".4f",vmin=-1, vmax=1, linewidths=.5, cmap = sns.diverging_palette(148, 302, s=60, as_cmap=True))

    #plt.yticks(rotation=0)
    plt.show()
    
    #feature importance using corr
    
    df.drop('Churn', axis=1).corrwith(df.Churn).plot(kind='barh', figsize=(8, 6), color='skyblue', title="Churn vs all features")

# %%
def main():
    # Load dataset
    df = readData('../data/churn_final.csv')
    countplot('Churn','ageGroup','charge_amount','complains',df)
    
    print('\n******************************************************************************************************')
    Distribution_plot(df)
    print('\n******************************************************************************************************')
    pie(df)
    print('\n******************************************************************************************************')
    boxplot(df)
    print('\n******************************************************************************************************')
    pairplot(df)
    print('\n******************************************************************************************************')
    correlation(df)
    print('\n******************************************************************************************************')
    plotHeatMap(df)
    
    matrix_df = pps.matrix(df).pivot(columns='x', index='y',  values='ppscore')

    sns.heatmap(matrix_df, annot=True)

# %%
main()
# Out:
# Count plot - The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable
#
# We will display the target variable and check for data imbalance using this Count plot (if there are more number of churn customers than customers who wont churn or vice versa)
#
# Observation1:
# There is some data imbalance, as the number of churn consumers is significantly lower than the number of customers that will not churn
#
# Using count plot, lets see the frequency/count of different age group
#
# Agegroup Range
# [0-15]    :   1
# [15-30]   :   2
# [30-45]   :   3
# [45-60]   :   4
# [60-80]   :   5
# [<0,>80]  :   2
#
# Observation2:
# There are more people between the ages of 15 and 45
#
# Charge amount is an ordinal attribute with lowest value being 0 and highest being 9
#
# Observation3:
# The charge amount of 0 has the highest count
#
# ******************************************************************************************************
# Observation1
#  We observe that there are many customers who are in the age group 30-60 and  are less likely to churn
# Observation2
#  We observe that the difference in count is huge between churn and non churn active customers(where active customers are more likely to not churn) as that of churn and non churn inactive customers
# Observation3
#  We observe that more number of customers have 0 call failures and hence 0 complaints
# Observation4
#  We observe that more number of customers who are in the age group of 30-60 have charge amount as o which refers to lowest pay
#
# ******************************************************************************************************
# Observation
# As we can see from the pie chart, most of the customers are of the age group 30-45
#
# ******************************************************************************************************
# outlier analysis using box-plot
# Observation
# As we can see there are outliers in our dataset, especially in seconds_of_use column we have more outliers
#
# ******************************************************************************************************
# ******************************************************************************************************
#
# ******************************************************************************************************
